# %%
# Rotate Array
arr = [1,2,3,4,5,6,7]
first = arr [:4]
last = arr[6:3:-1]

while first < last :
    arr[first], arr[last] = arr[last], arr[first]
    first += 1
    last -= 1
print(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4 last = arr[6:3:-1]
#       6 while first < last :
# ----> 7     arr[first], arr[last] = arr[last], arr[first]
#       8     first += 1
#       9     last -= 1
#
# TypeError: list indices must be integers or slices, not list
